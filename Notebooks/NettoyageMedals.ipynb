# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("olympic_medals.xlsx", index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21697 entries, 0 to 21696
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   discipline_title       21697 non-null  object
#  1   slug_game              21697 non-null  object
#  2   event_title            21697 non-null  object
#  3   event_gender           21697 non-null  object
#  4   medal_type             21697 non-null  object
#  5   participant_type       21697 non-null  object
#  6   participant_title      6584 non-null   object
#  7   athlete_url            17027 non-null  object
#  8   athlete_full_name      18073 non-null  object
#  9   country_name           21697 non-null  object
#  10  country_code           20195 non-null  object
#  11  country_3_letter_code  21697 non-null  object
# dtypes: object(12)
# memory usage: 2.2+ MB

# %%
# Valeurs nulles
df.isnull().sum()
# Out:
# discipline_title             0
# slug_game                    0
# event_title                  0
# event_gender                 0
# medal_type                   0
# participant_type             0
# participant_title        15113
# athlete_url               4670
# athlete_full_name         3624
# country_name                 0
# country_code              1502
# country_3_letter_code        0
# dtype: int64

# %%
# remove useless columns
df = df.drop(columns=['participant_title', 'athlete_url', 'athlete_full_name', 'country_code', 'country_name'])
df.columns
# Out:
# Index(['discipline_title', 'slug_game', 'event_title', 'event_gender',
#        'medal_type', 'participant_type', 'country_3_letter_code'],
#       dtype='object')

# %%
# Visualiser les doublons
duplicates = df.duplicated()
df[duplicates]
# Il n'y a pas de doublons
# Out:
#           discipline_title     slug_game                 event_title  \
# 1                  Curling  beijing-2022               Mixed Doubles
# 3                  Curling  beijing-2022               Mixed Doubles
# 5                  Curling  beijing-2022               Mixed Doubles
# 82               Snowboard  beijing-2022  Mixed Team Snowboard Cross
# 84               Snowboard  beijing-2022  Mixed Team Snowboard Cross
# ...                    ...           ...                         ...
# 21602            Athletics   athens-1896               high jump men
# 21633  Gymnastics Artistic   athens-1896      team parallel bars men
# 21683               Tennis   athens-1896                 doubles men
# 21685               Tennis   athens-1896                 doubles men
# 21687               Tennis   athens-1896                 doubles men
#
#       event_gender medal_type participant_type country_3_letter_code
# 1            Mixed       GOLD         GameTeam                   ITA
# 3            Mixed     SILVER         GameTeam                   NOR
# 5            Mixed     BRONZE         GameTeam                   SWE
# 82           Mixed       GOLD         GameTeam                   USA
# 84           Mixed     SILVER         GameTeam                   ITA
# ...            ...        ...              ...                   ...
# 21602          Men     SILVER          Athlete                   USA
# 21633          Men     BRONZE         GameTeam                   GRE
# 21683          Men       GOLD         GameTeam                   MIX
# 21685          Men     SILVER         GameTeam                   GRE
# 21687          Men     BRONZE         GameTeam                   MIX
#
# [1526 rows x 7 columns]

# %%
# Enlever les éditions d'hiver
df['slug_game'].unique()

winter_games = [
    'beijing-2022', 'pyeongchang-2018', 'sochi-2014', 'vancouver-2010', 
    'turin-2006', 'salt-lake-city-2002', 'nagano-1998', 'lillehammer-1994', 
    'albertville-1992', 'calgary-1988', 'sarajevo-1984', 'lake-placid-1980', 
    'innsbruck-1976', 'sapporo-1972', 'grenoble-1968', 'innsbruck-1964', 
    'squaw-valley-1960', 'cortina-d-ampezzo-1956', 'oslo-1952', 
    'st-moritz-1948', 'garmisch-partenkirchen-1936', 'lake-placid-1932', 
    'st-moritz-1928', 'chamonix-1924'
]

# Les éditions qui ne sont pas dans les jeux d'hiver
summer_games = df[~df['slug_game'].isin(winter_games)]
summer_games
# Out:
#       discipline_title    slug_game                      event_title  \
# 355           Shooting   tokyo-2020                  Trap Mixed Team
# 356           Shooting   tokyo-2020                  Trap Mixed Team
# 357           Shooting   tokyo-2020                  Trap Mixed Team
# 358           Shooting   tokyo-2020                  Trap Mixed Team
# 359           Shooting   tokyo-2020                  Trap Mixed Team
# ...                ...          ...                              ...
# 21692    Weightlifting  athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting  athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting  athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting  athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting  athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type country_3_letter_code
# 355          Mixed       GOLD         GameTeam                   ESP
# 356          Mixed       GOLD         GameTeam                   ESP
# 357          Mixed     SILVER         GameTeam                   SMR
# 358          Mixed     SILVER         GameTeam                   SMR
# 359          Mixed     BRONZE         GameTeam                   USA
# ...            ...        ...              ...                   ...
# 21692          Men     SILVER          Athlete                   DEN
# 21693          Men     BRONZE          Athlete                   GRE
# 21694          Men       GOLD          Athlete                   DEN
# 21695          Men     SILVER          Athlete                   GBR
# 21696          Men     BRONZE          Athlete                   GRE
#
# [17919 rows x 7 columns]

# %%
# Filter les données à partir de 2000

# Création d'une colonne year en se basant sur la colonne slug_game
df['year'] = df['slug_game'].str.extract(r'(\d{4})').astype(int)
del df['slug_game']

# %%
df = df[df['year'] >= 2000]
df
# Out:
#      discipline_title       event_title event_gender medal_type  \
# 0             Curling     Mixed Doubles        Mixed       GOLD
# 1             Curling     Mixed Doubles        Mixed       GOLD
# 2             Curling     Mixed Doubles        Mixed     SILVER
# 3             Curling     Mixed Doubles        Mixed     SILVER
# 4             Curling     Mixed Doubles        Mixed     BRONZE
# ...               ...               ...          ...        ...
# 8183        Taekwondo  57 - 67 kg women        Women     SILVER
# 8184        Taekwondo  57 - 67 kg women        Women     BRONZE
# 8185        Taekwondo       49 kg women        Women       GOLD
# 8186        Taekwondo       49 kg women        Women     SILVER
# 8187        Taekwondo       49 kg women        Women     BRONZE
#
#      participant_type country_3_letter_code  year
# 0            GameTeam                   ITA  2022
# 1            GameTeam                   ITA  2022
# 2            GameTeam                   NOR  2022
# 3            GameTeam                   NOR  2022
# 4            GameTeam                   SWE  2022
# ...               ...                   ...   ...
# 8183          Athlete                   NOR  2000
# 8184          Athlete                   JPN  2000
# 8185          Athlete                   AUS  2000
# 8186          Athlete                   CUB  2000
# 8187          Athlete                   TPE  2000
#
# [8188 rows x 7 columns]

# %%
# Supprimer les disciplines qui ne sont pas dans la prochaine édition


# Trouver les disciplines unique tous JO confondus
disciplines = df['discipline_title'].unique()
disciplines

# Seules ces discplines sont présentes dans l'édition 2024
disciplines_2024 = ['Figure skating',
       'Shooting', 'Diving', 'Canoe Sprint', 'Cycling Road', 'Football', 'Boxing',
       'Artistic Swimming', 'Handball', 'Rugby Sevens',
       'Cycling BMX Racing', 'Triathlon', 'Surfing', 'Table Tennis',
       'Canoe Slalom', 'Marathon Swimming', 'Trampoline Gymnastics',
       'Volleyball', 'Basketball', 'Taekwondo', 'Cycling Track',
       'Fencing', 'Badminton', 'Water Polo', 'Sport Climbing',
       'Wrestling', 'Tennis', 'Artistic Gymnastics', 'Golf',
       'Cycling BMX Freestyle', 'Judo', 'Skateboarding', 'Archery',
       'Weightlifting',
       'Modern Pentathlon', 'Athletics', 'Swimming', 'Sailing',
       'Cycling Mountain Bike', 'Rowing', '3x3 Basketball',
       'Rhythmic Gymnastics', 'Hockey', 'Beach Volleyball',
       'Cycling BMX', 'Rugby', 'Gymnastics Rhythmic', 'Gymnastics Artistic',
       'Synchronized Swimming', 'Trampoline'
    ]

# Ne garder que les données en rapport avec ces disciplines
df = df[df['discipline_title'].isin(disciplines_2024)]
df

df['discipline_title'].unique()
# Out:
# array(['Figure skating', 'Shooting', 'Diving', 'Canoe Sprint',
#        'Cycling Road', 'Football', 'Boxing', 'Artistic Swimming',
#        'Handball', 'Rugby Sevens', 'Cycling BMX Racing', 'Triathlon',
#        'Surfing', 'Table Tennis', 'Canoe Slalom', 'Marathon Swimming',
#        'Trampoline Gymnastics', 'Volleyball', 'Basketball', 'Taekwondo',
#        'Cycling Track', 'Fencing', 'Badminton', 'Water Polo',
#        'Sport Climbing', 'Wrestling', 'Tennis', 'Artistic Gymnastics',
#        'Golf', 'Cycling BMX Freestyle', 'Judo', 'Skateboarding',
#        'Archery', 'Weightlifting', 'Modern Pentathlon', 'Athletics',
#        'Swimming', 'Sailing', 'Cycling Mountain Bike', 'Rowing',
#        '3x3 Basketball', 'Rhythmic Gymnastics', 'Hockey',
#        'Beach Volleyball', 'Cycling BMX', 'Rugby', 'Gymnastics Rhythmic',
#        'Gymnastics Artistic', 'Synchronized Swimming', 'Trampoline'],
#       dtype=object)

# %%
# Rassembler Gymnastics Rhythmic et Rhythmic Gymnastics dans une même colonne
df.loc[:,'discipline_title'] = df['discipline_title'].replace('Gymnastics Rhythmic', 'Rhythmic Gymnastics')

# Rassembler Artistic Gymnastics et Gymnastics Artistic dans une même colonne
df.loc[:,'discipline_title'] = df['discipline_title'].replace('Artistic Gymnastics', 'Gymnastics Artistic')

# %%
df[df['discipline_title'] == 'Artistic Gymnastics'] # 0 left
df[df['discipline_title'] == 'Gymnastics Artistic']

df[df['discipline_title'] == 'Gymnastics Rhythmic'] # 0 left
df[df['discipline_title'] == 'Rhythmic Gymnastics']
# Out:
#          discipline_title                  event_title event_gender  \
# 1519  Rhythmic Gymnastics        Individual All-Around        Women
# 1520  Rhythmic Gymnastics        Individual All-Around        Women
# 1521  Rhythmic Gymnastics        Individual All-Around        Women
# 1522  Rhythmic Gymnastics             Group All-Around        Women
# 1523  Rhythmic Gymnastics             Group All-Around        Women
# 1524  Rhythmic Gymnastics             Group All-Around        Women
# 1898  Rhythmic Gymnastics       Group All-Around women        Women
# 1899  Rhythmic Gymnastics       Group All-Around women        Women
# 1900  Rhythmic Gymnastics       Group All-Around women        Women
# 1901  Rhythmic Gymnastics  Individual All-Around women        Women
# 1902  Rhythmic Gymnastics  Individual All-Around women        Women
# 1903  Rhythmic Gymnastics  Individual All-Around women        Women
# 4199  Rhythmic Gymnastics      group competition women        Women
# 4200  Rhythmic Gymnastics      group competition women        Women
# 4201  Rhythmic Gymnastics      group competition women        Women
# 4202  Rhythmic Gymnastics   individual all-round women        Women
# 4203  Rhythmic Gymnastics   individual all-round women        Women
# 4204  Rhythmic Gymnastics   individual all-round women        Women
# 5334  Rhythmic Gymnastics      group competition women        Women
# 5335  Rhythmic Gymnastics      group competition women        Women
# 5336  Rhythmic Gymnastics      group competition women        Women
# 5337  Rhythmic Gymnastics   individual all-round women        Women
# 5338  Rhythmic Gymnastics   individual all-round women        Women
# 5339  Rhythmic Gymnastics   individual all-round women        Women
# 6426  Rhythmic Gymnastics   individual all-round women        Women
# 6427  Rhythmic Gymnastics   individual all-round women        Women
# 6428  Rhythmic Gymnastics   individual all-round women        Women
# 6429  Rhythmic Gymnastics      group competition women        Women
# 6430  Rhythmic Gymnastics      group competition women        Women
# 6431  Rhythmic Gymnastics      group competition women        Women
# 7677  Rhythmic Gymnastics   individual all-round women        Women
# 7678  Rhythmic Gymnastics   individual all-round women        Women
# 7679  Rhythmic Gymnastics   individual all-round women        Women
# 7680  Rhythmic Gymnastics      group competition women        Women
# 7681  Rhythmic Gymnastics      group competition women        Women
# 7682  Rhythmic Gymnastics      group competition women        Women
#
#      medal_type participant_type country_3_letter_code  year
# 1519     SILVER          Athlete                   ROC  2020
# 1520     BRONZE          Athlete                   BLR  2020
# 1521       GOLD          Athlete                   ISR  2020
# 1522       GOLD         GameTeam                   BUL  2020
# 1523     SILVER         GameTeam                   ROC  2020
# 1524     BRONZE         GameTeam                   ITA  2020
# 1898       GOLD         GameTeam                   RUS  2016
# 1899     SILVER         GameTeam                   ESP  2016
# 1900     BRONZE         GameTeam                   BUL  2016
# 1901       GOLD          Athlete                   RUS  2016
# 1902     SILVER          Athlete                   RUS  2016
# 1903     BRONZE          Athlete                   UKR  2016
# 4199       GOLD         GameTeam                   RUS  2012
# 4200     SILVER         GameTeam                   BLR  2012
# 4201     BRONZE         GameTeam                   ITA  2012
# 4202       GOLD          Athlete                   RUS  2012
# 4203     SILVER          Athlete                   RUS  2012
# 4204     BRONZE          Athlete                   BLR  2012
# 5334       GOLD         GameTeam                   RUS  2008
# 5335     SILVER         GameTeam                   CHN  2008
# 5336     BRONZE         GameTeam                   BLR  2008
# 5337       GOLD          Athlete                   RUS  2008
# 5338     SILVER          Athlete                   BLR  2008
# 5339     BRONZE          Athlete                   UKR  2008
# 6426       GOLD          Athlete                   RUS  2004
# 6427     SILVER          Athlete                   RUS  2004
# 6428     BRONZE          Athlete                   UKR  2004
# 6429       GOLD         GameTeam                   RUS  2004
# 6430     SILVER         GameTeam                   ITA  2004
# 6431     BRONZE         GameTeam                   BUL  2004
# 7677       GOLD          Athlete                   RUS  2000
# 7678     SILVER          Athlete                   BLR  2000
# 7679     BRONZE          Athlete                   RUS  2000
# 7680       GOLD         GameTeam                   RUS  2000
# 7681     SILVER         GameTeam                   BLR  2000
# 7682     BRONZE         GameTeam                   GRE  2000

# %%
df.isnull().sum()
# Out:
# discipline_title         0
# event_title              0
# event_gender             0
# medal_type               0
# participant_type         0
# country_3_letter_code    0
# year                     0
# dtype: int64

# %%
df['participant_type'].unique()
# df['event_title'].unique()
# Out:
# array(['GameTeam', 'Athlete'], dtype=object)

# %%
# Remplacer les valeurs qualitative par des valeurs numériques

# columns_to_encode = ['discipline_title', 'event_title', 'event_gender', 'medal_type', 'participant_type']


# df.loc[:,'discipline_title'] = pd.factorize(df['discipline_title'])[0]
# df.loc[:,'event_title'] = pd.factorize(df['event_title'])[0]
# df.loc[:,'event_gender'] = pd.factorize(df['event_gender'])[0]

# # df.loc[:,'medal_type'] = pd.factorize(df['medal_type'])[0]
# mapping = {'BRONZE': 0, 'SILVER': 1, 'GOLD': 2}
# df.loc[:,'medal_type'] = df['medal_type'].map(mapping)


# df.loc[:,'participant_type'] = pd.factorize(df['participant_type'])[0]

df.rename(columns={'country_3_letter_code': 'country_code'}, inplace=True)
df
# Out:
# C:\Users\classico\AppData\Local\Temp\ipykernel_13052\323147580.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'country_3_letter_code': 'country_code'}, inplace=True)
#      discipline_title       event_title event_gender medal_type  \
# 129    Figure skating        Team Event        Mixed       GOLD
# 130    Figure skating        Team Event        Mixed       GOLD
# 131    Figure skating        Team Event        Mixed     SILVER
# 132    Figure skating        Team Event        Mixed     BRONZE
# 133    Figure skating      Pair Skating        Mixed       GOLD
# ...               ...               ...          ...        ...
# 8183        Taekwondo  57 - 67 kg women        Women     SILVER
# 8184        Taekwondo  57 - 67 kg women        Women     BRONZE
# 8185        Taekwondo       49 kg women        Women       GOLD
# 8186        Taekwondo       49 kg women        Women     SILVER
# 8187        Taekwondo       49 kg women        Women     BRONZE
#
#      participant_type country_code  year
# 129          GameTeam          ROC  2022
# 130          GameTeam          ROC  2022
# 131          GameTeam          USA  2022
# 132          GameTeam          JPN  2022
# 133          GameTeam          CHN  2022
# ...               ...          ...   ...
# 8183          Athlete          NOR  2000
# 8184          Athlete          JPN  2000
# 8185          Athlete          AUS  2000
# 8186          Athlete          CUB  2000
# 8187          Athlete          TPE  2000
#
# [6341 rows x 7 columns]

# %%
# Enregistrer le dataframe dans un nouveau fichier csv
df.to_csv('filtered_data.csv', index=False)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6341 entries, 129 to 8187
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   discipline_title  6341 non-null   object
#  1   event_title       6341 non-null   object
#  2   event_gender      6341 non-null   object
#  3   medal_type        6341 non-null   object
#  4   participant_type  6341 non-null   object
#  5   country_code      6341 non-null   object
#  6   year              6341 non-null   int32
# dtypes: int32(1), object(6)
# memory usage: 371.5+ KB
